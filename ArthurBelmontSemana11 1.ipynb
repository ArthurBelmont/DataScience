# %% [markdown]
# # Introdução a DataScience

# %%
import pandas as pd
import pathlib
import numpy as np

meses = {'jan': 1, 'fev':2, 'mar':3, 'abr': 4, 'mai':5, 'jun': 6, 'jul': 7, 'ago': 8, 'set': 9, 'out': 10, 'nov': 11, 'dez': 12}

caminho_bases = pathlib.Path('dataset')

base_airbnb = pd.DataFrame()

for arquivo in caminho_bases.iterdir():
    nome_mes = arquivo.name[:3]
    mes = meses[nome_mes]
    
    ano = arquivo.name[-8:]
    ano = int(ano.replace('.csv', ''))
    
    df = pd.read_csv(caminho_bases / arquivo.name, low_memory=False)
    df['ano'] = ano
    df['mes'] = mes
    base_airbnb = base_airbnb.append(df)

display(base_airbnb)
# Out:
#              id                            listing_url       scrape_id  \
# 0         14063     https://www.airbnb.com/rooms/14063  20180414160018
# 1         17878     https://www.airbnb.com/rooms/17878  20180414160018
# 2         24480     https://www.airbnb.com/rooms/24480  20180414160018
# 3         25026     https://www.airbnb.com/rooms/25026  20180414160018
# 4         31560     https://www.airbnb.com/rooms/31560  20180414160018
# ...         ...                                    ...             ...
# 34324  38844730  https://www.airbnb.com/rooms/38844730  20190923212307
# 34325  38846408  https://www.airbnb.com/rooms/38846408  20190923212307
# 34326  38846703  https://www.airbnb.com/rooms/38846703  20190923212307
# 34327  38847050  https://www.airbnb.com/rooms/38847050  20190923212307
# 34328  38847655  https://www.airbnb.com/rooms/38847655  20190923212307
#
#       last_scraped                                          name  \
# ...

# %%
df.describe()
# Out:
#                  id     scrape_id  thumbnail_url  medium_url  xl_picture_url  \
# count  3.432900e+04  3.432900e+04            0.0         0.0             0.0
# mean   1.744310e+07  2.019092e+13            NaN         NaN             NaN
# std    1.106711e+07  8.824347e+00            NaN         NaN             NaN
# min    1.787800e+04  2.019092e+13            NaN         NaN             NaN
# 25%    9.992237e+06  2.019092e+13            NaN         NaN             NaN
# 50%    1.413587e+07  2.019092e+13            NaN         NaN             NaN
# 75%    2.740455e+07  2.019092e+13            NaN         NaN             NaN
# max    3.884766e+07  2.019092e+13            NaN         NaN             NaN
#
#             host_id  host_acceptance_rate  host_listings_count  \
# count  3.432900e+04                   0.0         34315.000000
# mean   7.015939e+07                   NaN             9.302288
# std    7.122795e+07                   NaN            39.530907
# ...

# %%
df[df['host_listings_count']==1]

#Quantos locais para alugar possuem/possuiram somente 1 dono.
# Out:
#              id                            listing_url       scrape_id  \
# 2         31560     https://www.airbnb.com/rooms/31560  20190923212307
# 3         35636     https://www.airbnb.com/rooms/35636  20190923212307
# 4         35764     https://www.airbnb.com/rooms/35764  20190923212307
# 5         35893     https://www.airbnb.com/rooms/35893  20190923212307
# 18        68422     https://www.airbnb.com/rooms/68422  20190923212307
# ...         ...                                    ...             ...
# 34302  38825971  https://www.airbnb.com/rooms/38825971  20190923212307
# 34308  38834816  https://www.airbnb.com/rooms/38834816  20190923212307
# 34314  38838783  https://www.airbnb.com/rooms/38838783  20190923212307
# 34316  38839579  https://www.airbnb.com/rooms/38839579  20190923212307
# 34323  38844100  https://www.airbnb.com/rooms/38844100  20190923212307
#
#       last_scraped                                               name  \
# ...

# %%
df[df['review_scores_location']==2]

# Imóvel com somente duas avaliações
# Out:
#              id                            listing_url       scrape_id  \
# 797      902627    https://www.airbnb.com/rooms/902627  20190923212307
# 3357    2809732   https://www.airbnb.com/rooms/2809732  20190923212307
# 6542    6575762   https://www.airbnb.com/rooms/6575762  20190923212307
# 9585   10752710  https://www.airbnb.com/rooms/10752710  20190923212307
# 11051  11797344  https://www.airbnb.com/rooms/11797344  20190923212307
# 12266  12709948  https://www.airbnb.com/rooms/12709948  20190923212307
# 13085  13114493  https://www.airbnb.com/rooms/13114493  20190923212307
# 17024  14109286  https://www.airbnb.com/rooms/14109286  20190923212307
# 18801  15523647  https://www.airbnb.com/rooms/15523647  20190923212307
# 19908  16884374  https://www.airbnb.com/rooms/16884374  20190923212307
# 20750  18140400  https://www.airbnb.com/rooms/18140400  20190923212307
# 21256  19485929  https://www.airbnb.com/rooms/19485929  20190923212307
# ...

# %%
a_2019 = df[df['ano']== 2019]

a_2019
# Out:
#              id                            listing_url       scrape_id  \
# 0         17878     https://www.airbnb.com/rooms/17878  20190923212307
# 1         25026     https://www.airbnb.com/rooms/25026  20190923212307
# 2         31560     https://www.airbnb.com/rooms/31560  20190923212307
# 3         35636     https://www.airbnb.com/rooms/35636  20190923212307
# 4         35764     https://www.airbnb.com/rooms/35764  20190923212307
# ...         ...                                    ...             ...
# 34324  38844730  https://www.airbnb.com/rooms/38844730  20190923212307
# 34325  38846408  https://www.airbnb.com/rooms/38846408  20190923212307
# 34326  38846703  https://www.airbnb.com/rooms/38846703  20190923212307
# 34327  38847050  https://www.airbnb.com/rooms/38847050  20190923212307
# 34328  38847655  https://www.airbnb.com/rooms/38847655  20190923212307
#
#       last_scraped                                            name  \
# ...

# %%
df.head(5)
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  17878  https://www.airbnb.com/rooms/17878  20190923212307   2019-09-24
# 1  25026  https://www.airbnb.com/rooms/25026  20190923212307   2019-09-24
# 2  31560  https://www.airbnb.com/rooms/31560  20190923212307   2019-09-24
# 3  35636  https://www.airbnb.com/rooms/35636  20190923212307   2019-09-24
# 4  35764  https://www.airbnb.com/rooms/35764  20190923212307   2019-09-24
#
#                                              name  \
# 0               Very Nice 2Br - Copacabana - WiFi
# 1       Beautiful Modern Decorated Studio in Copa
# 2                NICE & COZY 1BDR - IPANEMA BEACH
# 3                Cosy flat close to Ipanema beach
# 4  COPACABANA SEA BREEZE  -  RIO - 20 X Superhost
#
#                                              summary  \
# 0  Please note that special rates apply for Carni...
# 1  Our apartment is a little gem, everyone loves ...
# ...

# %%
df.tail(10)
# Out:
#              id                            listing_url       scrape_id  \
# 34319  38840364  https://www.airbnb.com/rooms/38840364  20190923212307
# 34320  38840372  https://www.airbnb.com/rooms/38840372  20190923212307
# 34321  38840607  https://www.airbnb.com/rooms/38840607  20190923212307
# 34322  38842769  https://www.airbnb.com/rooms/38842769  20190923212307
# 34323  38844100  https://www.airbnb.com/rooms/38844100  20190923212307
# 34324  38844730  https://www.airbnb.com/rooms/38844730  20190923212307
# 34325  38846408  https://www.airbnb.com/rooms/38846408  20190923212307
# 34326  38846703  https://www.airbnb.com/rooms/38846703  20190923212307
# 34327  38847050  https://www.airbnb.com/rooms/38847050  20190923212307
# 34328  38847655  https://www.airbnb.com/rooms/38847655  20190923212307
#
#       last_scraped                                          name  \
# 34319   2019-09-24             TRANSAMERICA BARRA DA TIJUCA R.II
# ...

# %% [markdown]
# ## Arthur Belmont Frazão
# ## 0050015602
#
# ### Por se tratar de uma base de dados gigantesca, consegui perceber um pouco o que é ser um DataScientist.
# Através dessas informações da para obter uma análise específica, fazendo com que haja a compreensão ou melhoria do que foi requisitado.
#
# Peguei uma base de dados do airbnb do RIO, vendo preços de algueis em varias regiões.
